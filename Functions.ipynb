# %%
#non parameterized function
def my_func(): #Function definition
    print("Hello from my_func")

# %%
my_func() #Function callable
my_func()
my_func()
# Out:
# Hello from my_func
# Hello from my_func
# Hello from my_func

# %%
#parameterized function
#non return function
def sum(num1, num2): #parameters
    print(num1 + num2)

# %%
a = sum(10, 20) #arguments
# Out:
# 30

# %%
print(a)
# Out:
# None

# %%
def name(fname):
    print("Hello", fname)

# %%
name("Areeba")
# Out:
# Hello Areeba

# %%
#return function
def func(x):
    return 5*x

a = func(3)
print(a)
# Out:
# 15

# %%
print(a)
# Out:
# 15

# %%
#default parameterized function
def my_country(country = "India"):
    print("I am from "+ country)

my_country("USA")
my_country("Pakistan")
my_country("UK")
my_country()
# Out:
# I am from USA
# I am from Pakistan
# I am from UK
# I am from India

# %% [markdown]
# Built - in Methods

# %%
import math

# %%
print(math.sqrt(16))
print(math.pow(2, 3))
print(math.pi)
print(math.e)
print(math.factorial(5))
print(math.gcd(12, 15))
print(math.sin(90))
print(math.cos(90))
print(math.tan(90))
print(math.lcm(12,15))
print(math.log(10))
# Out:
# 4.0
# 8.0
# 3.141592653589793
# 2.718281828459045
# 120
# 3
# 0.8939966636005579
# -0.4480736161291701
# -1.995200412208242
# 60
# 2.302585092994046

# %%
from random import random, randint, choice, shuffle

# %%
print('get a random number between 0 and 1:', random())
print('get a random number between 1 and 100:', randint(1, 100))
print('get a random number from a list:', choice([1, 2, 3, 4, 5]))
names = ['Areeba', 'Ali', 'Ahmed', 'Asad', 'Ahsan']
shuffle(names)
print('shuffle a list:', names)
# Out:
# get a random number between 0 and 1: 0.7782872730414785
# get a random number between 1 and 100: 47
# get a random number from a list: 3
# shuffle a list: ['Ahsan', 'Ahmed', 'Asad', 'Areeba', 'Ali']

# %%
from datetime import datetime as dt

# %%
print('Current Date and Time :', dt.now())
print('Current Date :', dt.now().date())
print('Current Time :', dt.now().time())
print('Current Year :', dt.now().year)
print('Current Month :', dt.now().month)
print('Current Day :', dt.now().day)
print('Current Hour :', dt.now().hour)
print('Current Minute :', dt.now().minute)
print('Current Second :', dt.now().second)
print('Current Microsecond :', dt.now().microsecond)
# Out:
# Current Date and Time : 2024-12-21 18:21:58.411961
# Current Date : 2024-12-21
# Current Time : 18:21:58.412952
# Current Year : 2024
# Current Month : 12
# Current Day : 21
# Current Hour : 18
# Current Minute : 21
# Current Second : 58
# Current Microsecond : 425283

# %%
date = dt.strftime(dt.now(), '%d/%m/%Y')
print('Date in dd-mm-yyyy format :', date)
# Out:
# Date in dd-mm-yyyy format : 21/12/2024

# %%
time = dt.strftime(dt.now(), '%H:%M:%S')
print('Time in 24 hour format :', time)
# Out:
# Time in 24 hour format : 18:34:54

# %%
import os

# %%
print('Current Working Directory :', os.getcwd())
# Out:
# Current Working Directory : c:\Users\LENOVO\Documents\DP-2024-PYTHON-5.30

# %%
files = os.listdir() # list all files and folders in current directory
print('Files in current directory :', files)
print(len(files), 'files found')
# Out:
# Files in current directory : ['.git', 'basics.ipynb', 'Conditions.ipynb', 'Data Structures', 'datatypes.ipynb', 'Functions.ipynb', 'loops.ipynb', 'operators.ipynb', 'prog1.py']
# 9 files found

# %%
file = os .listdir(r"C:\Users\LENOVO\Documents\AI-Extension-Project")
print('Files in current directory :', file)
print(len(file), 'files found')
# Out:
# Files in current directory : ['Frontend', 'gesture-plugin', 'package-lock.json', 'package.json', 'qna-plugin', 'testing']
# 6 files found

# %%
os.walk(r"C:\Users\LENOVO\Documents\AI-Extension-Project")
# Out:
# <generator object walk at 0x000001AB47E00D30>

# %%
total_files = 0
for path, folders, files in os.walk(r"C:\Users\LENOVO\Documents\AI-Extension-Project"):
    total_files += len(files)
    print('=>', path)
    print('📂', folders)
    print('📄', files)
print(total_files, 'files found')
# Out:
# => C:\Users\LENOVO\Documents\AI-Extension-Project
# 📂 ['Frontend', 'gesture-plugin', 'qna-plugin', 'testing']
# 📄 ['package-lock.json', 'package.json']
# => C:\Users\LENOVO\Documents\AI-Extension-Project\Frontend
# 📂 ['.parcel-cache', 'node_modules', 'public', 'src']
# 📄 ['.eslintrc.cjs', '.gitignore', 'index.html', 'package-lock.json', 'package.json', 'README.md', 'vite.config.js']
# => C:\Users\LENOVO\Documents\AI-Extension-Project\Frontend\.parcel-cache
# 📂 []
# 📄 ['19d52dfa74f3b908-AssetGraph-0', 'data.mdb', 'e5e6f52d0218a721-AssetGraph-0', 'lock.mdb', 'requestGraph-207c666a25ef5248-0', 'requestGraph-85a69beeda036642-0', 'requestGraph-nodes-0-207c666a25ef5248-0', 'requestGraph-nodes-0-85a69beeda036642-0', 'snapshot-207c666a25ef5248.txt', 'snapshot-85a69beeda036642.txt']
# => C:\Users\LENOVO\Documents\AI-Extension-Project\Frontend\node_modules
# ...
